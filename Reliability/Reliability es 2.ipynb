# %%
import pandas as pd
import numpy as np
import seaborn as sn
import io
import os
import pathlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import ward, fcluster
from scipy.spatial.distance import pdist
from bioinfokit.visuz import cluster
import dataframe_image as dfi

# %%
def esponenziale (x,l) :
    return np.exp(-l*x)

r = np.linspace(0,1,1000)

s=4
m=2
m_1=m**s

rels1= 1-(1-r**s)**m
rels2= (1-(1-r)**m)**s
rels1_1 = 1-(1-r**s)**m_1
 
plt.figure(figsize = (20, 10))
plt.plot(r,rels1,label='Sistema 1')
plt.plot(r,rels2,label='Sistema 2',color='red')
plt.legend(loc='upper left',fontsize = 'x-large')
plt.title('Confronto sistemi S1 - S2', size=22)
plt.xlabel('r', size=16)
plt.ylabel('Reliability', size=16)
plt.grid()
plt.show()

plt.figure(figsize = (20, 10))
plt.plot(r,rels1_1,label='Sistema 1 modificato')
plt.plot(r,rels2,label='Sistema 2',color='red')
plt.legend(loc='upper left',fontsize = 'x-large')
plt.title('Confronto sistemi S1\' - S2', size=22)
plt.xlabel('r', size=16)
plt.ylabel('Reliability', size=16)
plt.grid()
plt.show()
